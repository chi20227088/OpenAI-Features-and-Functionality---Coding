# %% [markdown]
# <a href="https://colab.research.google.com/github/chi20227088/OpenAI-Features-and-Functionality---Coding/blob/main/Ph%E1%BA%A3n_h%E1%BB%93i_d%E1%BA%A1ng_Streaming_t%E1%BB%AB_OpenAI_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install openai --quiet

# %% [markdown]
# # Streaming API Responses
#
# In this notebook, we demonstrate how to stream responses from the OpenAI API using the Responses API.
#
# By default, the API generates the entire output before returning it. Using streaming, you can begin processing the response as the model generates output, which is useful for long completions or when you want to display partial results immediately.
#
# In our example, we'll ask the model to recite the tongue twister "Peter Piper picked a peck of pickled peppers" five times. We then loop through the streamed events and print each event, allowing you to see how the response is built incrementally.
#
# ### Key Streaming Event Types (for reference):
#
# - `response.created`
# - `response.output_text.delta`
# - `response.completed`
# - `error`
#
# For a full list, refer to the API reference.
#
# # Khi bạn gọi API với stream=True, model sẽ:
#
# Sinh từng phần nhỏ của phản hồi (gọi là delta)
#
# Gửi ngay cho bạn mỗi phần vừa sinh ra
#
# Giúp bạn hiển thị nội dung theo thời gian thực

# %% [markdown]
# ## Code Example: Streaming a Tongue Twister
#
# The following code demonstrates how to enable streaming by setting `stream=True` in your request. The example uses a different prompt to show how events are emitted and processed on-the-fly.

# %%
from openai import OpenAI

# %%
MODEL = "gpt-4.1-mini"

# %%
# Create an OpenAI client instance
client = OpenAI(
    # Replace with your actual API key or use: api_key=os.environ.get("OPENAI_API_KEY")
    api_key="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"
)

# %%
# Request the model to recite the tongue twister five times using streaming
stream = client.responses.create(
    model=MODEL,
    input=[{
        "role": "user",
        "content": "Recite 'Peter Piper picked a peck of pickled peppers' five times in a row."
    }],
    stream=True
)

# Iterate over streaming events and print details
for event in stream:
    # Depending on the event type, you can handle it accordingly
    if hasattr(event, 'type'): #kiểm tra xem sự kiện này có thuộc tính 'type' (response.created, response.output_text.delta...)
        print(f"Event Type: {event.type}")
    # If the event includes a delta with content, print it
    if hasattr(event, 'delta') and event.delta: #nếu sự kiện có chứa nội dung văn bản 'delta'
        print(f"Delta Content: {event.delta}") #In ra nội dung văn bản mà model vùa sinh ra
    # Print a separator for clarity
    print("-------------------------")
# Out:
# Event Type: response.created
# -------------------------
# Event Type: response.in_progress
# -------------------------
# Event Type: response.output_item.added
# -------------------------
# Event Type: response.content_part.added
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: Peter
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Piper
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  picked
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  a
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pe
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: ck
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  of
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pick
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: led
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  peppers
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: .
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Peter
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Piper
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  picked
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  a
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pe
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: ck
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  of
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pick
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: led
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  peppers
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: .
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Peter
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Piper
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  picked
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  a
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pe
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: ck
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  of
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pick
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: led
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  peppers
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: .
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Peter
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Piper
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  picked
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  a
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pe
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: ck
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  of
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pick
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: led
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  peppers
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: .
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Peter
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  Piper
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  picked
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  a
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pe
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: ck
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  of
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  pick
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: led
# -------------------------
# Event Type: response.output_text.delta
# Delta Content:  peppers
# -------------------------
# Event Type: response.output_text.delta
# Delta Content: .
# -------------------------
# Event Type: response.output_text.done
# -------------------------
# Event Type: response.content_part.done
# -------------------------
# Event Type: response.output_item.done
# -------------------------
# Event Type: response.completed
# -------------------------

# %%
# Request the model to recite the tongue twister five times using streaming
stream = client.responses.create(
    model=MODEL,
    input=[{
        "role": "user",
        "content": "Recite 'Peter Piper picked a peck of pickled peppers' five times in a row."
    }],
    stream=True
)

text = ''

# Iterate over streaming events and print details
for event in stream:
    # Depending on the event type, you can handle it accordingly
    if event.type == 'response.output_text.delta':
        text += event.delta
        print(text)
        print("------------------------")
# Out:
# Sure
# ------------------------
# Sure!
# ------------------------
# Sure! Here
# ------------------------
# Sure! Here it
# ------------------------
# Sure! Here it is
# ------------------------
# Sure! Here it is:
#
#
# ------------------------
# Sure! Here it is:
#
# Peter
# ------------------------
# Sure! Here it is:
#
# Peter Piper
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a pe
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pick
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers.
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a pe
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pick
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers.
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a pe
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pick
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers.
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a pe
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pick
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers.
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a pe
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pick
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers
# ------------------------
# Sure! Here it is:
#
# Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers. Peter Piper picked a peck of pickled peppers.
# ------------------------

# %%
MODEL = "gpt-4o-mini"
stream = client.responses.create(
    model = MODEL,
    input = [{"role": "user", "content": "Hãy cho biết thủ đô của Việt Nam"}],
    stream = True
)
text =''
for event in stream:
  if event.type == 'response.output_text.delta':
    text += event.delta
    print(text)
# Out:
# Th
# Thủ
# Thủ đô
# Thủ đô của
# Thủ đô của Việt
# Thủ đô của Việt Nam
# Thủ đô của Việt Nam là
# Thủ đô của Việt Nam là Hà
# Thủ đô của Việt Nam là Hà Nội
# Thủ đô của Việt Nam là Hà Nội.

# %% [markdown]
# ## Summary
#
# - **Streaming Enabled:** By setting `stream=True` in the API request, we stream the model's output incrementally.
# - **Event Handling:** The code loops over each event, printing its type and any text deltas as they are generated.
# - **Example Prompt:** We used a tongue twister prompt as a different example to show that you can stream various types of outputs.
#
# This notebook provides a basic starting point for leveraging streaming responses to optimize for latency or real-time display of model output.
